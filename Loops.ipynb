# %% [markdown]
# <a href="https://colab.research.google.com/github/aacayanan/cisc179-assignments/blob/main/Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loops in Python
#
# A sequence of instructions that repeats until a certain condition is met
#
# ## Objective
# Understand how loops are applied
#
# ## Prerequisite
#
# - Decision statements
# - Input functions
# - Python literals
# - Programming variables
#
# ## What do you need to complete this exercise?
#
# You can perform this exercise in any Python IDE, including JupyterLab or Google Colab.

# %% [markdown]
# ### While loop
#
# a. Please write Python code using a while loop to perform the following steps.
#
# 1. Take any non-negative and non-zero integer number and name it ```n0```
# 2. if the number is even, evaluate a new ```n0``` as ```n0 ÷ 2```;
# 3. Otherwise, if the number is odd, evaluate a new ```n0``` as ```3 * n0 + 1```;
# 4. if ```n0``` is not equal to 1, go to point 2.
#
# #### Sample input: ```16```
#
# #### Expected output: ###
#
# ```
# 8
# 4
# 2
# 1
# steps = 4
# ```

# %%
# Write your code here.
n0 = int(input("Enter any non-zero integer number: "))
count = 0

while(n0 != 1):
  # check if number is even
  if n0 % 2 == 0:
    n0 = int(n0 / 2)
  else:
    # must be odd
    n0 = int(3 * n0 + 1)
  print(n0)
  count += 1
print(f"steps = {count}")
# Out:
# Enter any non-zero integer number: 16
# 8
# 4
# 2
# 1
# steps = 4

# %% [markdown]
# b. Write code that uses a while loop and runs indefinitely. Modify the same code to resolve the infinite loop issue.

# %%
# Write your code here.
i = 1
while (i != 0):
  i += 1
print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-1a409e99ad40> in <cell line: 0>()
#       1 # Write your code here.
#       2 i = 1
# ----> 3 while (i != 0):
#       4   i += 1
#       5 print(i)
#
# KeyboardInterrupt:

# %%
# resolved infinite loop issue
i = 1
while (i != 0 and i <= 10):
  i += 1
print(i)
# Out:
# 11

# %% [markdown]
# c. Write a program that takes two integers as input and asks the user to choose an arithmetic operation to perform with those numbers. At the end of the program, prompt the user with the question, "Do you want to continue?" If the user selects "Y" or "y," the program should restart; otherwise, it should exit and display the message, "Have a good day."

# %%
# Write your code here.
continue_input = ""
while (continue_input.upper() != "N"):
  input_1 = int(input("Enter an integer: "))
  input_2 = int(input("Enter another integer: "))
  operation_input = int(input("Select an arithmetic operation: \n1. +\n2. -\n3. *\n4. /\n"))
  match (operation_input):
    case 1:
      print(f"Your result is: {input_1 + input_2}")
    case 2:
      print(f"Your result is: {input_1 - input_2}")
    case 3:
      print(f"Your result is: {input_1 * input_2}")
    case 4:
      print(f"Your result is: {input_1 / input_2}")
    case _:
      print("Error: you must select a valid option.")
  continue_input = input("Do you want to continue? (y/n) ")
print("Have a good day.")
# Out:
# Enter an integer: 1
# Enter another integer: 2
# Select an arithmetic operation:
# 1. +
# 2. -
# 3. *
# 4. /
# 1
# Your result is: 3
# Do you want to continue? (y/n) y
# Enter an integer: 1
# Enter another integer: 4
# Select an arithmetic operation:
# 1. +
# 2. -
# 3. *
# 4. /
# 4
# Your result is: 0.25
# Do you want to continue? (y/n) Y
# Enter an integer: 3
# Enter another integer: 2
# Select an arithmetic operation:
# 1. +
# 2. -
# 3. *
# 4. /
# 3
# Your result is: 6
# Do you want to continue? (y/n) n
# Have a good day.

# %% [markdown]
# ### 2. For loops
#
# a. Write a code that counts the total number of characters in a text and also counts each character individually. For example, consider the sentence "To be, or not to be, that is the question." The code should determine the total number of letters and how many times each letter appears, including specific counts for the letters 't' and 'o', etc. Ignore the upper and lower cases letters, and any punctuations symbols. Use only for loop, while loop, break and continue statements where necessary.
#
# #### Sample input: ```To be, or not to be, that is the question```
#
# #### Expected output: ###
#
# ```
# Total number of alphabets: 30
# Total number of distinct alphabets are:
# T = 7
# o = 4
# ```
# > **Note:** The expected output above is incomplete.

# %%
# Write your code here.
sample_text = "To be, or not to be, that is the question"
count = 0
t_count = 0
o_count = 0
for char in sample_text:
  if char.lower().isalpha():
    count += 1
  else:
    continue
  if char.lower() == 't':
    t_count += 1
  if char.lower() == 'o':
    o_count += 1
print(f"Total number of alphabets: {count}")
print(f"T = {t_count}")
print(f"o = {o_count}")
# Out:
# Total number of alphabets: 30
# T = 7
# o = 5

# %% [markdown]
# ## Challenges
#
# Please describe the challenges you faced during the exercise.

# %% [markdown]
# Write your challenges here
#
# The greatest challenge that I faced during this exercice was the logic behind the while loop when trying to continue the program in practice 1c. I initially set the while condition to 'y' and thought that would work but it didn't work as expected. I then realized that the while loop will only execute if the condition is set to True, and when I set it to a False condition only then will it exit the while loop.
