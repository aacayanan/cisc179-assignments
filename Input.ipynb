# %% [markdown]
# <a href="https://colab.research.google.com/github/aacayanan/cisc179-assignments/blob/main/Input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # User input in Python
#
# ## Objective
# 1. Understand how ```input()``` function is applied.
#
# ## Prerequisite
#
# - Python literals lecture & lab
# - Programming variables lecture
#
# ## What do you need to complete this exercise?
#
# You can perform this exercise in any Python IDE, including JupyterLab or Google Colab.

# %% [markdown]
# ### User input
#
# a. Write a program that prompts the user to enter the weight of a person in kilograms and outputs the equivalent weight in pounds. (Note that 1 kilogram = 2.2 pounds).

# %%
# Write your code here
user_input = input("Enter your weight in kg: ")
print(f"You are {round(float(user_input) * 2.2, 2)} pounds.")
# Hint: Use int() or float() to convert the user input into an integer or float
x = "10"
print(type(x))
x = int(x)
print(type(x))
# Out:
# Enter your weight in kg: 32
# You are 70.4 pounds.
# <class 'str'>
# <class 'int'>

# %% [markdown]
# b. Interest on a credit card's unpaid balance is calculated using the average daily balance. Suppose that $netBalance$ is the balance shown in the bill, $payment$ is the payment made, $d1$ is the number of days in the billing cycle, and $d2$ is the number of days payment is made before biling cycle. Then, the average daily balance is: $$averageDailybalance = (netBalance \times d1 - payment \times d2)/d1$$.
#
# If the interest rate per month is, say, 0.0152, then the interest on the unpaid balance is: $interest = averageDailyBalance \times 0.0152$
#
# Write a program that accepts as input $netBalance$, $payment$, $d1$, $d2$, and $interest rate per month$. The program outputs the interest.

# %%
# Write your code here
net_balance = float(input("Enter the net balance amount: "))
payment = float(input("Enter the payment amount: "))
d1 = float(input("Enter the number of days in billing cycle: "))
d2 = float(input("Enter the number of days payment is made before billing cycle: "))
average_daily_bal = (net_balance * d1 - payment * d2) / d1
interest = average_daily_bal * 0.0152
print(f"The interest is: {round(interest, 2)}")
# Out:
# Enter the net balance amount: 32000
# Enter the payment amount: 24000.01
# Enter the number of days in billing cycle: 30
# Enter the number of days payment is made before billing cycle: 4
# The interest is: 437.76

# %% [markdown]
# c. Two cars A and B leave an intersection at the same time. Car A travels west at an average speed of x miles per hour and car B travels south at an average speed of y miles per hour. Write a program that prompts the user to enter the average speed of both the cars and the elapsed time (in hours and minutes) and outputs the (shortest) distance between the cars.

# %%
# Write your code here
car_a_mph = float(input("Enter the speed (mph) Car A is going: "))
car_b_mph = float(input("Enter the speed (mph) Car B is going: "))
time_hours = int(input("How many hours elapsed? Enter whole numbers only: "))
time_minutes = int(input("How many minutes past? Enter whole numbers only: "))
total_time = float(time_minutes / 60) + time_hours
print(f"Shortest distance between the cars is {abs(round((car_a_mph * total_time) - (car_b_mph * total_time), 2))} miles.")
# Out:
# Enter the speed (mph) Car A is going: 21
# Enter the speed (mph) Car B is going: 20
# How many hours elapsed? Enter whole numbers only: 1
# How many minutes past? Enter whole numbers only: 30
# Shortest distance between the cars is 1.5 miles.

# %% [markdown]
# ### Troubleshooting
#
# Please troubleshoot the following issue **without using Python**, and explain your reasoning.
#
# a. ```hello = "hello"```
# b. ```_var = 100```
# c. ```!var_1 = 200```
# d. ```print = "print me"```
# e. ```False = 0```

# %% [markdown]
# Write your answer here
#
# a) No issue.
#
# b) No issue.
#
# c) Remove the '!'. A variable can not start with a special character like '!'.
#
# d) Choose a different variable name. 'print' is already a built-in Python function.
#
# e) False is a reserved word meaning it cannot be reassigned. To fix this we must change the variable name.

# %% [markdown]
# ## Challenges
#
# Please describe the challenges you faced during the exercise.

# %% [markdown]
# Write your challenges here
#
# Honestly, the most challenging part about this exercise was battling the internet connection as my interest is spotty and I am traveling right now. But in terms of the actual lab, I was trying to create this code without writing anything down so I had to conceptualize it in my head.
