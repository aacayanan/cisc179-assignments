# %% [markdown]
# <a href="https://colab.research.google.com/github/aacayanan/cisc179-assignments/blob/main/Python_literals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python literals
#
# ## Objective
# 1. Understand how Python uses literals.
# 2. Differentiate Integer, Float, Boolean and String data types.
# 3. Understanding how arithmetic operations are performed and recognizing the precedence of operators.
#
# ## Prerequisite
#
# - Python & literals lecture
#
# ## What do you need to complete this exercise?
#
# You can perform this exercise in any Python IDE, including JupyterLab or Google Colab.

# %% [markdown]
# ### Literals
#
# a) What will the output be without using Python? Aim for 80% accuracy.
#
# ```print(5 + 2 - 2)```
#
# ```print(5 / 2)```
#
# ```print(6 // 2) # // integer division```
#
# ```print(2. * 3)```
#
# ```print(2 < 4)```
#
# ```print(2 >= 2)```
#
# ```print("Hello"+"World")```
#
# ```print("bla" * 3)```
#
# ```print(2 * 3 ** 3)```
#
# ```print(5 * 25 // 13 + 100 / 2 % 13 // 2)```
#
# ```print(2 * 3 % 5)```
#
# ```print((2 % -4), (2 % 4), (2 ** 3 ** 2))```

# %% [markdown]
# Without using Python
#
# 5
#
# 2.5
#
# 3
#
# 6.00
#
# True
#
# True
#
# HelloWorld
#
# blablabla
#
# 54
#
# 14
#
# 1
#
# -2 2 512

# %% [markdown]
# b) Please verify using Python to determine if you have achieved at least 80% correct answers.

# %%
# Write your code here
print(5 + 2 - 2)

print(5 / 2)

print(6 // 2) # // integer division

print(2. * 3)

print(2 < 4)

print(2 >= 2)

print("Hello"+"World")

print("bla" * 3)

print(2 * 3 ** 3)

print(5 * 25 // 13 + 100 / 2 % 13 // 2)

print(2 * 3 % 5)

print((2 % -4), (2 % 4), (2 ** 3 ** 2))
# Out:
# 5
# 2.5
# 3
# 6.0
# True
# True
# HelloWorld
# blablabla
# 54
# 14.0
# 1
# -2 2 512

# %% [markdown]
# ### Data type

# %% [markdown]
# a) What will the output be without using Python? Aim for 80% accuracy.
# ```type("Hello")```
#
# ```type(1+"2")```
#
# ```type(1.)```
#
# ```type('A')```
#
# ```type(500)```
#
# ```type(True)```
#
# ```type("False")```

# %% [markdown]
# Answer here
#
# String
#
# Error
#
# Float
#
# Char
#
# Int
#
# Boolean
#
# String

# %% [markdown]
# b) Please verify using Python to determine if you have achieved at least 80% correct answers.

# %%
# Write your code here
type("False")
# Out:
# str

# %% [markdown]
# ### Operator precedence

# %% [markdown]
# a) Write your arithmetic expression that uses at least one operator from each group. For example ```5 * 25 % 13 + 100 / -2 * 13 // 2 ** 3```

# %%
# Write your code here
print((10 % 2) / 4 + 2 ** 2 // 1 - 300 * 2)

# %% [markdown]
# b) What will the output be without using Python after writing your arithmetic expression? Use the table below for your reference.

# %% [markdown]
# | Priority | Operator                                                     | Notes                    |
# | :------- | :----------------------------------------------------------- | :----------------------- |
# | 1        | `**`                                                         | Right to left evaluation |
# | 2        | `+`, `-` (note: unary operators located next to the right of the power operator bind more strongly) | unary                    |
# | 3        | `*`, `/`, `//`, `%`                                          | Left to right evaluation |
# | 4        | `+`, `-`                                                     | binary                   |

# %% [markdown]
# Answer here
#
# -596

# %% [markdown]
# c) Please verify using Python to determine if you have done it correctly.

# %%
# Write your code here
print((10 % 2) / 4 + 2 ** 2 // 1 - 300 * 2)
# Out:
# -596.0

# %% [markdown]
# ## Challenges
#
# Please describe the challenges you faced during the exercise.

# %% [markdown]
# Write your challenges here
#
# Challenges I found was trying to wrap my head around '//' because it confuses me with the '**' operator as they are similar in syntax but different in what they do. I now figured out that the '//' operator floors the problem. Another thing that confused me was why my final arithmetic expression I wrote was a floating point number but I realized it's because of the modulo operator.
